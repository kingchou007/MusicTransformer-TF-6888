# %%
from model import MusicTransformer
from custom.layers import *
from custom import callback
from tensorflow import keras
import params as par
from tensorflow.keras.optimizers import Adam

from data import Data
import utils
tf.executing_eagerly()
# Out:
# True

# %%
l_r = 0.0024 #@param {type:"slider", min:0, max:0.1, step:0.0001}
batch_size = 3 #@param {type:"slider", min:1, max:100, step:1}
pickle_dir = "processed/" #@param {type:"string"}
max_seq = 2048 #@param {type:"slider", min:1, max:3000, step:1}
epochs = 1416 #@param {type:"slider", min:1, max:10000, step:1}
model_save_path = "result/test" #@param {type:"string"}

# %%
dataset = Data('dataset/processed/')
opt = Adam(0.001)
model = MusicTransformer(
    embedding_dim=par.embedding_dim, 
    vocab_size=par.vocab_size, 
    num_layer=6, 
    max_seq=max_seq,
    debug=False)
model.compile(optimizer=opt, loss=callback.TransformerLoss())
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/kingchou/Documents/6888/Music-Transformer-TensorFlow/music-transformer-train.ipynb Cell 3 line 9
#       <a href='vscode-notebook-cell:/Users/kingchou/Documents/6888/Music-Transformer-TensorFlow/music-transformer-train.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> opt = Adam(0.001)
#       <a href='vscode-notebook-cell:/Users/kingchou/Documents/6888/Music-Transformer-TensorFlow/music-transformer-train.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> model = MusicTransformer(
#       <a href='vscode-notebook-cell:/Users/kingchou/Documents/6888/Music-Transformer-TensorFlow/music-transformer-train.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a>     embedding_dim=par.embedding_dim,
#       <a href='vscode-notebook-cell:/Users/kingchou/Documents/6888/Music-Transformer-TensorFlow/music-transformer-train.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a>     vocab_size=par.vocab_size,
#       <a href='vscode-notebook-cell:/Users/kingchou/Documents/6888/Music-Transformer-TensorFlow/music-transformer-train.ipynb#W6sZmlsZQ%3D%3D?line=5'>6</a>     num_layer=6,
#       <a href='vscode-notebook-cell:/Users/kingchou/Documents/6888/Music-Transformer-TensorFlow/music-transformer-train.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a>     max_seq=max_seq,
#       <a href='vscode-notebook-cell:/Users/kingchou/Documents/6888/Music-Transformer-TensorFlow/music-transformer-train.ipynb#W6sZmlsZQ%3D%3D?line=7'>8</a>     debug=False)
# ----> <a href='vscode-notebook-cell:/Users/kingchou/Documents/6888/Music-Transformer-TensorFlow/music-transformer-train.ipynb#W6sZmlsZQ%3D%3D?line=8'>9</a> model.compile(optimizer=opt, loss=callback.TransformerLoss())
#
# File ~/anaconda3/envs/6888/lib/python3.11/site-packages/tensorflow/python/keras/engine/training.py:568, in Model.compile(self, optimizer, loss, metrics, loss_weights, weighted_metrics, run_eagerly, steps_per_execution, **kwargs)
#     565 self._validate_compile(optimizer, metrics, **kwargs)
#     566 self._run_eagerly = run_eagerly
# --> 568 self.optimizer = self._get_optimizer(optimizer)
#     569 self.compiled_loss = compile_utils.LossesContainer(
#     570     loss, loss_weights, output_names=self.output_names)
#     571 self.compiled_metrics = compile_utils.MetricsContainer(
#     572     metrics, weighted_metrics, output_names=self.output_names,
#     573     from_serialized=from_serialized)
#
# File ~/anaconda3/envs/6888/lib/python3.11/site-packages/tensorflow/python/keras/engine/training.py:606, in Model._get_optimizer(self, optimizer)
#     603       opt = lso.LossScaleOptimizerV1(opt, loss_scale)
#     604   return opt
# --> 606 return nest.map_structure(_get_single_optimizer, optimizer)
#
# File ~/anaconda3/envs/6888/lib/python3.11/site-packages/tensorflow/python/util/nest.py:631, in map_structure(func, *structure, **kwargs)
#     545 @tf_export("nest.map_structure")
#     546 def map_structure(func, *structure, **kwargs):
#     547   """Creates a new structure by applying `func` to each atom in `structure`.
#     548
#     549   Refer to [tf.nest](https://www.tensorflow.org/api_docs/python/tf/nest)
#    (...)
#     629     ValueError: If wrong keyword arguments are provided.
#     630   """
# --> 631   return nest_util.map_structure(
#     632       nest_util.Modality.CORE, func, *structure, **kwargs
#     633   )
#
# File ~/anaconda3/envs/6888/lib/python3.11/site-packages/tensorflow/python/util/nest_util.py:1066, in map_structure(modality, func, *structure, **kwargs)
#     969 """Creates a new structure by applying `func` to each atom in `structure`.
#     970
#     971 - For Modality.CORE: Refer to
#    (...)
#    1063   ValueError: If wrong keyword arguments are provided.
#    1064 """
#    1065 if modality == Modality.CORE:
# -> 1066   return _tf_core_map_structure(func, *structure, **kwargs)
#    1067 elif modality == Modality.DATA:
#    1068   return _tf_data_map_structure(func, *structure, **kwargs)
#
# File ~/anaconda3/envs/6888/lib/python3.11/site-packages/tensorflow/python/util/nest_util.py:1106, in _tf_core_map_structure(func, *structure, **kwargs)
#    1101 flat_structure = (_tf_core_flatten(s, expand_composites) for s in structure)
#    1102 entries = zip(*flat_structure)
#    1104 return _tf_core_pack_sequence_as(
#    1105     structure[0],
# -> 1106     [func(*x) for x in entries],
#    1107     expand_composites=expand_composites,
#    1108 )
#
# File ~/anaconda3/envs/6888/lib/python3.11/site-packages/tensorflow/python/util/nest_util.py:1106, in <listcomp>(.0)
#    1101 flat_structure = (_tf_core_flatten(s, expand_composites) for s in structure)
#    1102 entries = zip(*flat_structure)
#    1104 return _tf_core_pack_sequence_as(
#    1105     structure[0],
# -> 1106     [func(*x) for x in entries],
#    1107     expand_composites=expand_composites,
#    1108 )
#
# File ~/anaconda3/envs/6888/lib/python3.11/site-packages/tensorflow/python/keras/engine/training.py:597, in Model._get_optimizer.<locals>._get_single_optimizer(opt)
#     596 def _get_single_optimizer(opt):
# --> 597   opt = optimizers.get(opt)
#     598   if (loss_scale is not None and
#     599       not isinstance(opt, lso.LossScaleOptimizer)):
#     600     if loss_scale == 'dynamic':
#
# File ~/anaconda3/envs/6888/lib/python3.11/site-packages/tensorflow/python/keras/optimizers.py:127, in get(identifier)
#     125   return deserialize(config)
#     126 else:
# --> 127   raise ValueError(
#     128       'Could not interpret optimizer identifier: {}'.format(identifier))
#
# ValueError: Could not interpret optimizer identifier: <keras.src.optimizers.adam.Adam object at 0x2e8fb43d0>

# %% [markdown]
# # Train Model

# %%
    for e in range(epochs):
        for b in range(len(dataset.files) // batch_size):
            batch_x, batch_y = dataset.seq2seq_batch(batch_size, par.max_seq)
            result_metrics = mt.train_on_batch(batch_x, batch_y)
            if b % 100 == 0:
              print('===========================================\n')
              print('Loss: {:6.6}, Accuracy: {:3.2}'.format(result_metrics[0], result_metrics[1]))
              mt.save('mt-2048-h4-dim256.h5', )
# Out:
# ===========================================
#
# Loss: 5.81973, Accuracy: 9.2
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-11-de26e9408e62> in <module>()
#       6           print('===========================================\n')
#       7           print('Loss: {:6.6}, Accuracy: {:3.2}'.format(result_metrics[0], result_metrics[1]))
# ----> 8           mt.save('mt-2048-h4-dim256.h5')
#       9
#      10
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/network.py in save(self, filepath, overwrite, include_optimizer)
#    1305     if not self._is_graph_network:
#    1306       raise NotImplementedError(
# -> 1307           'The `save` method requires the model to be a Functional model or a '
#    1308           'Sequential model. It does not work for subclassed models, '
#    1309           'because such models are defined via the body of a Python method, '
#
# NotImplementedError: The `save` method requires the model to be a Functional model or a Sequential model. It does not work for subclassed models, because such models are defined via the body of a Python method, which isn't safely serializable. Consider using `save_weights`, in order to save the weights of the model.

# %% [markdown]
# # Generate Model

# %%
def fill_with_placeholder(prev_data: list, max_len: int, max_val: int=239):
    placeholder = [max_val for _ in range(max_len - len(prev_data))]
    return placeholder+prev_data

# %%
for i in range(max_seq):
